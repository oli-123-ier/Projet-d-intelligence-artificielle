# %%
import pandas as pd

file_path = 'F2013.xlsx'
excel_data = pd.ExcelFile(file_path)

excel_data.sheet_names
# Out:
# ['Sheet1']

# %%
import re

def convert_age_to_months(age):
    if pd.isna(age):
        return None
    years, months, days = 0, 0, 0
    match = re.search(r'(\d+)y', age)
    if match:
        years = int(match.group(1))
    match = re.search(r'(\d+)m', age)
    if match:
        months = int(match.group(1))
    match = re.search(r'(\d+)d', age)
    if match:
        days = int(match.group(1))
    return years * 12 + months + days // 30


# data['Age_in_months'] = data['Age'].apply(convert_age_to_months)
# data['Sexe'] = data['Sexe'].replace('F', 'F')
data['Sexe'] = data['Sexe'].str.strip()

stats_by_sex = data.groupby('Sexe')['Age_in_months'].agg(['mean', 'min', 'max', 'std'])
stats_by_sex
# Out:
#           mean  min  max        std
# Sexe
# F     9.813953    1   90  17.717701
# M     8.715789    1   48  10.624804

# %%
global_stats = data['Age_in_months'].agg(['mean', 'min', 'max', 'std'])
global_stats
# Out:
# mean     9.057971
# min      1.000000
# max     90.000000
# std     13.189117
# Name: Age_in_months, dtype: float64
