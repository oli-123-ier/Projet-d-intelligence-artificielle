# %% [markdown]
# ## **Lecture et Statistique des tableau**

# %%
import numpy as np
import pandas as pd

df_1 = pd.read_csv('/content/train.csv')
df_1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_1.describe(include=['category','object'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df_2 = pd.read_csv('/content/test.csv')
df_2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Display descriptive statistics for numerical columns
df_2.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
# Display descriptive statistics for categorical columns
df_2.describe(include=['category','object'])
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
df_3 = pd.read_csv('/content/gender_submission.csv')
df_3.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
# Display descriptive statistics for the dataframe
df_3.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %% [markdown]
# # **Traitement des données**

# %%
df_1.duplicated().sum()
# Out:
# 0

# %%
df_2.duplicated().sum()
# Out:
# 0

# %%
df_3.duplicated().sum()
# Out:
# 0

# %%
df_1['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df_2['Cabin'].value_counts()
# Out:
# Cabin
# B57 B59 B63 B66    3
# B45                2
# C89                2
# C55 C57            2
# A34                2
#                   ..
# E52                1
# D30                1
# E31                1
# C62 C64            1
# C105               1
# Name: count, Length: 76, dtype: int64

# %%
df_1['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df_1['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df_2['Embarked'].value_counts()
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
df_1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_1 = df_1.drop(['PassengerId', 'Name', 'Ticket','Cabin'], axis=1)

# %%
df_2 = df_2.drop(['PassengerId', 'Name', 'Ticket','Cabin'], axis=1)

# %%
df_1.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df_2.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  34.5      0      0   7.8292        Q
# 1       3  female  47.0      1      0   7.0000        S
# 2       2    male  62.0      0      0   9.6875        Q
# 3       3    male  27.0      0      0   8.6625        S
# 4       3  female  22.0      1      1  12.2875        S

# %%
df_1 = pd.get_dummies(df_1, columns=['Sex', 'Embarked'], drop_first=True).fillna(0).astype(int)

# %%
df_2 = pd.get_dummies(df_2, columns=['Sex', 'Embarked'], drop_first=True).fillna(0).astype(int)

# %%
df_1.head()
# Out:
#    Survived  Pclass  Age  SibSp  Parch  Fare  Sex_male  Embarked_Q  Embarked_S
# 0         0       3   22      1      0     7         1           0           1
# 1         1       1   38      1      0    71         0           0           0
# 2         1       3   26      0      0     7         0           0           1
# 3         1       1   35      1      0    53         0           0           1
# 4         0       3   35      0      0     8         1           0           1

# %%
df_2.head()
# Out:
#    Pclass  Age  SibSp  Parch  Fare  Sex_male  Embarked_Q  Embarked_S
# 0       3   34      0      0     7         1           1           0
# 1       3   47      1      0     7         0           0           1
# 2       2   62      0      0     9         1           1           0
# 3       3   27      0      0     8         1           0           1
# 4       3   22      1      1    12         0           0           1

# %%
x = df_1.drop('Survived',axis=1)
y = df_1['Survived']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
# Division des données en ensembles d'entraînement et de test
x = df_1.drop('Survived',axis=1)
y = df_1['Survived']

from imblearn.over_sampling import SMOTE

from sklearn.model_selection import train_test_split

# Apply SMOTE to balance the classes in the training set
smote = SMOTE(random_state=42)  # Use a random state for reproducibility
x_train_resampled, y_train_resampled = smote.fit_resample(x, y)

x_train, x_test, y_train, y_test = train_test_split(x_train_resampled, y_train_resampled, test_size=0.2, random_state=2)

print(x_train.shape)
y_train.shape
# Out:
# (878, 8)
# (878,)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (878, 8)
# (878,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_scaled = sc.fit_transform(x_train)
x_test_scaled = sc.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-0.26510134, -0.28802527, -0.45014727, ...,  0.89190864,
#         -0.29433597,  0.68427146],
#        [-1.44065172,  2.04193735, -0.45014727, ...,  0.89190864,
#         -0.29433597,  0.68427146],
#        [ 0.91044904, -1.36776405,  0.50682441, ...,  0.89190864,
#         -0.29433597, -1.46140832],
#        ...,
#        [-1.44065172,  1.47365378, -0.45014727, ..., -1.12119107,
#         -0.29433597, -1.46140832],
#        [-1.44065172,  2.66704927, -0.45014727, ...,  0.89190864,
#         -0.29433597, -1.46140832],
#        [-1.44065172, -1.36776405, -0.45014727, ...,  0.89190864,
#         -0.29433597,  0.68427146]])

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks
import matplotlib.pyplot as plt
from tensorflow.keras.regularizers import l1_l2



# Define the model

model = keras.Sequential([
    layers.Dense(8, activation='relu',
                 input_shape=(x_train_scaled.shape[1],)),
    layers.Dense(6, activation='relu'),
    layers.Dense(3, activation='relu'),

    layers.Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Define early stopping and ModelCheckpoint
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model_checkpoint = callbacks.ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, mode='max',
                                            verbose=1)

# Train the model with early stopping and model checkpoint
history = model.fit(x_train_scaled, y_train, epochs=350, batch_size=32, validation_split=0.1,
                    callbacks=[early_stopping, model_checkpoint])

# Load the best model
best_model = keras.models.load_model('best_model.keras')

# Evaluate the best model
loss, accuracy = best_model.evaluate(x_test_scaled, y_test)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")

# Make predictions
y_pred = model.predict(x_test_scaled)
y_pred = (y_pred > 0.5).astype(int)  # Convert probabilities to binary predictions

# Example: Print the first 10 predictions and true labels
for i in range(10):
    print(f"Prediction: {y_pred[i][0]}, True Label: {y_test.iloc[i]}")

# Récupérer les valeurs de perte et d'exactitude d'entraînement et de validation depuis l'objet History
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Créer un graphique pour montrer la perte d'entraînement et de validation au fil des époques
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train loss')
plt.plot(val_loss, label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Créer un graphique pour montrer l'exactitude d'entraînement et de validation au fil des époques
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Train accuracy')
plt.plot(val_accuracy, label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/350
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4682 - loss: 0.6974
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to best_model.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4700 - loss: 0.6972 - val_accuracy: 0.5000 - val_loss: 0.6949
# Epoch 2/350
#  1/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4062 - loss: 0.6964
# Epoch 2: val_accuracy improved from 0.50000 to 0.51136, saving model to best_model.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5163 - loss: 0.6947 - val_accuracy: 0.5114 - val_loss: 0.6914
# Epoch 3/350
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_df_2_scaled = sc.fit_transform(df_2)

# %%
x_df_2_scaled
# Out:
# array([[ 0.87348191,  0.56762911, -0.49947002, ...,  0.75592895,
#          2.84375747, -1.35067551],
#        [ 0.87348191,  1.30696195,  0.61699237, ..., -1.32287566,
#         -0.35164743,  0.74037028],
#        [-0.31581919,  2.16003831, -0.49947002, ...,  0.75592895,
#          2.84375747, -1.35067551],
#        ...,
#        [ 0.87348191,  0.79511614, -0.49947002, ...,  0.75592895,
#         -0.35164743,  0.74037028],
#        [ 0.87348191, -1.36601062, -0.49947002, ...,  0.75592895,
#         -0.35164743,  0.74037028],
#        [ 0.87348191, -1.36601062,  0.61699237, ...,  0.75592895,
#         -0.35164743, -1.35067551]])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Prédiction sur les données de test mises à l'échelle.
y_pred = model.predict(x_df_2_scaled)
y_pred
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# array([[0.19527373],
#        [0.51452935],
#        [0.19527373],
#        [0.15189101],
#        [0.60710055],
#        [0.1365157 ],
#        [0.5224506 ],
#        [0.3854834 ],
#        [0.8276032 ],
#        [0.07162425],
#        [0.0985245 ],
#        [0.5636908 ],
#        [0.9970868 ],
#        [0.0732202 ],
#        [0.991348  ],
#        [0.92670083],
#        [0.43493748],
#        [0.19527373],
#        [0.4576595 ],
#        [0.825196  ],
#        [0.48632842],
#        [0.42675886],
#        [0.999673  ],
#        [0.4261457 ],
#        [0.9208804 ],
#        [0.0779833 ],
#        [0.9988788 ],
#        [0.19527373],
#        [0.58571047],
#        [0.05087827],
#        [0.07987091],
#        [0.10843871],
#        [0.7203984 ],
#        [0.6034738 ],
#        [0.48156545],
#        [0.19527373],
#        [0.8742089 ],
#        [0.698847  ],
#        [0.15257528],
#        [0.40384164],
#        [0.19527373],
# ...

# %%
# Calcule et affiche l'exactitude du modèle.
# La fonction `accuracy_score` compare les valeurs prédites (y_pred, arrondies à l'entier le plus proche pour obtenir des prédictions binaires)
# aux vraies valeurs (y_test).
from sklearn.metrics import  accuracy_score
accuracy_score(df_3['Survived'] , y_pred.round())
# Out:
# 0.8899521531100478

# %%
# prompt: matrice de confusion

from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

# Assuming y_test contains the true labels and y_pred contains the predicted probabilities
# Convert predicted probabilities to binary predictions (0 or 1)
y_pred_binary = (y_pred > 0.5).astype(int)
y_pred_binary = np.ravel(y_pred_binary) # Flatten the y_pred_binary to a 1D array


# Assuming df_3['Survived'] contains the true labels for the test set
cm = confusion_matrix(df_3['Survived'], y_pred_binary)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
