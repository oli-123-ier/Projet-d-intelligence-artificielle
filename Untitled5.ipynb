# %%
# -*- coding: utf-8 -*-
# =====================================
#  CELLULE 1 : Installation et Setup
# =====================================
# Installez les bibliothèques nécessaires.
# !pip install nltk sumy scikit-learn requests beautifulsoup4 ipywidgets -q

# Importations principales
import nltk
import requests
from bs4 import BeautifulSoup
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer # Alternative: TextRankSummarizer, LexRankSummarizer
from sumy.nlp.stemmers import Stemmer
from sumy.utils import get_stop_words

from sklearn.feature_extraction.text import TfidfVectorizer
import ipywidgets as widgets
from IPython.display import display, clear_output

import warnings
warnings.filterwarnings('ignore') # Pour masquer les avertissements potentiels
import urllib.error # Pour attraper spécifiquement les erreurs réseau NLTK

# Téléchargement des ressources NLTK (version avec punkt_tab)
print("⬇️ Téléchargement des ressources NLTK nécessaires (punkt, stopwords, punkt_tab)...")
nltk_download_success = True
missing_resources = []
resources_to_download = [
    ('tokenizers/punkt', 'punkt'),
    ('corpora/stopwords', 'stopwords'),
    ('tokenizers/punkt_tab', 'punkt_tab') # Ajout de punkt_tab
]

try:
    for resource_path, resource_name in resources_to_download:
        print(f"--- Vérification de '{resource_name}' ---")
        try:
            nltk.data.find(resource_path)
            print(f"   [INFO] '{resource_name}' déjà présent.")
        except LookupError:
            print(f"   [ACTION] '{resource_name}' non trouvé. Tentative de téléchargement...")
            try:
                nltk.download(resource_name, quiet=True)
                # Vérifier à nouveau après la tentative de téléchargement
                nltk.data.find(resource_path)
                print(f"   [SUCCESS] '{resource_name}' téléchargé avec succès.")
            except urllib.error.URLError as e:
                print(f"   [ERREUR] Réseau pendant le téléchargement de '{resource_name}': {e}")
                missing_resources.append(resource_name)
                nltk_download_success = False
            except LookupError:
                print(f"   [ERREUR] Échec de la localisation de '{resource_name}' après tentative de téléchargement.")
                missing_resources.append(resource_name)
                nltk_download_success = False
            except Exception as e:
                 print(f"   [ERREUR] Inattendue pendant le téléchargement de '{resource_name}': {e}")
                 missing_resources.append(resource_name)
                 nltk_download_success = False

    # --- Message final sur les ressources NLTK ---
    if not missing_resources:
        print("✅ Ressources NLTK essentielles trouvées ou téléchargées.")
    else:
        print(f"⚠️ Certaines ressources NLTK n'ont pas pu être chargées : {', '.join(missing_resources)}")
        # nltk_download_success est déjà False si missing_resources n'est pas vide


except Exception as e:
    # Erreur générale en dehors des blocs de téléchargement
    print(f"❌ Erreur générale inattendue lors de la préparation des ressources NLTK : {e}")
    nltk_download_success = False

# Définition de la langue et des stop words
LANGUE = "french"
STOP_WORDS_FR_NLTK = []
STOP_WORDS_FR_SUMY = []

if nltk_download_success:
    try:
        STOP_WORDS_FR_NLTK = nltk.corpus.stopwords.words(LANGUE)
        STOP_WORDS_FR_SUMY = get_stop_words(LANGUE)
        print("✅ Stopwords français chargés.")
    except Exception as e:
        print(f"❌ Erreur lors du chargement des stopwords français : {e}")
        nltk_download_success = False

# --- Message final sur l'état de l'environnement ---
if nltk_download_success:
    print("✅ Environnement prêt.")
else:
    print("⚠️ Environnement partiellement prêt ou échec critique. Vérifiez les messages d'erreur NLTK ci-dessus.")


# =====================================
#  CELLULE 2 : Fonctions Utilitaires
# =====================================

def resumer_texte(texte, langue, nb_phrases):
    """
    Résume le texte donné en utilisant Sumy (LSA par défaut).
    """
    if not nltk_download_success:
         # Message plus précis basé sur les ressources manquantes si possible
         missing_str = ', '.join(missing_resources) if 'missing_resources' in globals() and missing_resources else "inconnues"
         return f"[ERREUR: RESSOURCES NLTK MANQUANTES ({missing_str})]"
    if not texte or not isinstance(texte, str) or texte.isspace():
        return "[Erreur: Texte vide ou invalide]"
    if not isinstance(nb_phrases, int) or nb_phrases <= 0:
        return "[Erreur: Nombre de phrases invalide]"

    try:
        # Utilisation explicite du tokenizer pour la langue spécifiée
        parser = PlaintextParser.from_string(texte, Tokenizer(langue))
        stemmer = Stemmer(langue)
        summarizer = LsaSummarizer(stemmer)
        # S'assurer que les stopwords sont bien ceux de la langue
        summarizer.stop_words = STOP_WORDS_FR_SUMY if STOP_WORDS_FR_SUMY else get_stop_words(langue)

        resume_phrases = summarizer(parser.document, nb_phrases)
        resume_final = " ".join([str(phrase) for phrase in resume_phrases])

        if not resume_final.strip():
             # Essayer d'obtenir le nombre total de phrases pour aider au diagnostic
             try:
                 total_phrases = len(parser.document.sentences)
                 return f"[Info: Le résumé généré est vide. Le texte original contient {total_phrases} phrases. Vérifiez le texte ou le nombre de phrases demandé ({nb_phrases}).]"
             except:
                 return "[Info: Le résumé généré est vide. Le texte original était peut-être trop court ou le nombre de phrases demandé trop élevé.]"
        return resume_final
    except LookupError as le:
        # Attraper spécifiquement les LookupError qui pourraient encore survenir
        return f"[Erreur NLTK pendant le résumé: Ressource manquante - {le}. Vérifiez l'installation NLTK.]"
    except Exception as e:
        # Inclure le type d'erreur pour faciliter le débogage
        return f"[Erreur pendant le résumé ({type(e).__name__}): {e}]"


def extraire_texte_url(url):
    """
    Extrait le contenu textuel principal d'une page web.
    """
    if not url or not url.startswith(('http://', 'https://')):
        return None, "URL invalide (doit commencer par http:// ou https://)."

    try:
        headers = {'User-Agent': 'Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)'}
        reponse = requests.get(url, headers=headers, timeout=15, allow_redirects=True)
        reponse.raise_for_status()
        reponse.encoding = reponse.apparent_encoding

        soup = BeautifulSoup(reponse.content, 'html.parser')

        for element in soup(["script", "style", "header", "footer", "nav", "aside", "form", "noscript", "img", "figure", "iframe"]):
            element.decompose() # Enlever plus d'éléments non textuels

        contenu_principal = soup.find('article') or soup.find('main') or soup.find(role='main')
        if not contenu_principal:
             contenu_principal = soup.find('body')

        if contenu_principal:
            # Remplacer les sauts de ligne par des espaces et nettoyer
            texte_brut = contenu_principal.get_text(separator=' ', strip=True)
        else:
             texte_brut = soup.get_text(separator=' ', strip=True)

        texte_nettoye = ' '.join(texte_brut.split())

        if not texte_nettoye or len(texte_nettoye) < 50: # Seuil minimum de caractères
             paragraphes = soup.find_all('p')
             if paragraphes:
                 texte_brut_p = ' '.join([p.get_text(strip=True) for p in paragraphes if p.get_text(strip=True)])
                 texte_nettoye_p = ' '.join(texte_brut_p.split())
                 # Utiliser la version <p> seulement si elle est significativement plus longue
                 if len(texte_nettoye_p) > len(texte_nettoye) * 1.2:
                      texte_nettoye = texte_nettoye_p

        if not texte_nettoye:
            return None, "Impossible d'extraire du contenu textuel significatif."

        return texte_nettoye, None

    except requests.exceptions.Timeout:
        return None, f"Erreur: Délai d'attente dépassé pour l'URL."
    except requests.exceptions.HTTPError as e:
         return None, f"Erreur HTTP {e.response.status_code}."
    except requests.exceptions.RequestException as e:
        # Essayer de donner une erreur plus spécifique si possible (ex: DNS, Connexion)
        error_type = type(e).__name__
        return None, f"Erreur de connexion ({error_type}). Vérifiez l'URL et la connexion."
    except Exception as e:
        return None, f"Erreur inattendue (analyse HTML?): {type(e).__name__}"


def extraire_mots_cles(texte, langue, nb_mots=7):
    """
    Extrait les mots-clés via TF-IDF.
    """
    if not nltk_download_success or not STOP_WORDS_FR_NLTK:
         print("[Avertissement: Mots-clés non extraits (ressources NLTK ou stopwords manquants)]")
         return []
    if not texte or not isinstance(texte, str) or texte.isspace() or len(texte.split()) < 5: # Besoin d'un minimum de mots
        print("[Info: Texte trop court pour l'extraction de mots-clés pertinents]")
        return []

    try:
        vectorizer = TfidfVectorizer(stop_words=STOP_WORDS_FR_NLTK, max_features=1000, ngram_range=(1, 2))
        tfidf_matrix = vectorizer.fit_transform([texte])

        feature_names = vectorizer.get_feature_names_out()
        scores = tfidf_matrix.toarray()[0]
        scored_words = zip(scores, feature_names)
        sorted_words = sorted(scored_words, key=lambda x: x[0], reverse=True)
        mots_cles = [word for score, word in sorted_words if score > 0.02][:nb_mots] # Seuil légèrement augmenté

        return mots_cles
    except ValueError as ve:
        if "empty vocabulary" in str(ve):
            print("[Info: Vocabulaire vide après filtrage pour TF-IDF]")
            return []
        else:
            print(f"[Avertissement: Erreur TF-IDF (ValueError): {ve}]")
            return []
    except Exception as e:
        print(f"[Avertissement: Erreur TF-IDF (Inattendue): {e}]")
        return []

# =====================================
#  CELLULE 3 : Interface Chatbot (Texte) - Pas de changements majeurs nécessaires ici
# =====================================
def lancer_chatbot_texte():
    """Lance l'interaction principale du chatbot en mode texte."""
    if not nltk_download_success:
        missing_str = ', '.join(missing_resources) if 'missing_resources' in globals() and missing_resources else "inconnues"
        print(f"❌ Le chatbot ne peut pas démarrer car les ressources NLTK essentielles ({missing_str}) n'ont pas pu être chargées.")
        print("   Veuillez vérifier les messages d'erreur ci-dessus et ré-exécuter la cellule.")
        return

    print("\n" + "="*50)
    print("🤖 Bonjour ! Je suis votre assistant résumeur de texte.")
    print("="*50)

    while True:
        print("\nQue souhaitez-vous faire ?")
        print("1. Résumer un texte que vous allez coller.")
        print("2. Résumer le contenu d'une page web (via URL).")
        print("3. Quitter.")

        choix = ""
        try:
            choix = input("Votre choix (1, 2 ou 3) : ").strip()
        except EOFError: print("\nEntrée fermée. Arrêt."); break
        except KeyboardInterrupt: print("\nInterruption détectée. Arrêt."); break

        if choix == '1':
            print("\n🤖 Très bien ! Collez votre texte ci-dessous (Entrée sur ligne vide pour finir):")
            lignes = []
            try:
                while True:
                    ligne = input()
                    if ligne or ligne == "": # Accepter ligne vide pour finir
                         if ligne: lignes.append(ligne)
                         elif lignes: break # Arrêter si ligne vide ET on a déjà du texte
                         else: print("   (Continuez à coller ou Entrée sur ligne vide pour finir)") # Rappel si vide au début
                    # Si input() retourne None ou autre chose (ne devrait pas arriver normalement)
                    # else:
                    #     if lignes: break
                    #     else: print("\nSaisie invalide/annulée."); lignes=None; break

            except EOFError:
                if not lignes: print("\nSaisie annulée (EOF)."); continue
                print("\nFin de saisie détectée (EOF).")
            except KeyboardInterrupt: print("\nSaisie annulée (Ctrl+C)."); continue

            if not lignes: continue

            texte_utilisateur = "\n".join(lignes)
            print(f"\n🤖 Texte reçu ! ({len(texte_utilisateur)} caractères)")

            nb_phrases = 0
            while True:
                try:
                    nb_phrases_str = input("Combien de phrases pour le résumé ? (Nombre > 0) : ").strip()
                    if not nb_phrases_str: continue
                    nb_phrases = int(nb_phrases_str)
                    if nb_phrases > 0: break
                    else: print("❌ Nombre positif requis.")
                except ValueError: print("❌ Entrée invalide (nombre entier requis).")
                except (KeyboardInterrupt, EOFError): print("\nOpération annulée."); nb_phrases = -1; break

            if nb_phrases <= 0: continue

            print(f"\n🤖 Génération du résumé ({nb_phrases} phrases)...")
            resume = resumer_texte(texte_utilisateur, LANGUE, nb_phrases)
            print("\n--- Résumé ---")
            print(resume)
            print("--- Fin du Résumé ---")

            print("\n🤖 Extraction des mots-clés...")
            mots_cles = extraire_mots_cles(texte_utilisateur, LANGUE, nb_mots=7)
            if mots_cles:
                print("\n--- Mots-Clés (max 7) ---")
                print(", ".join(mots_cles))
                print("--- Fin des Mots-Clés ---")

        elif choix == '2':
            url = ""
            try:
                 url = input("\n🤖 Entrez l'URL de la page web : ").strip()
                 if not url: print("❌ URL vide."); continue
            except (KeyboardInterrupt, EOFError): print("\nOpération annulée."); continue

            print(f"\n🤖 Extraction du texte de : {url}...")
            texte_extrait, erreur = extraire_texte_url(url)

            if erreur:
                print(f"❌ Erreur URL : {erreur}")
                continue

            if texte_extrait:
                print(f"✅ Texte extrait ({len(texte_extrait)} caractères)")
                nb_phrases = 0
                while True:
                    try:
                        nb_phrases_str = input("Combien de phrases pour le résumé ? (Nombre > 0) : ").strip()
                        if not nb_phrases_str: continue
                        nb_phrases = int(nb_phrases_str)
                        if nb_phrases > 0: break
                        else: print("❌ Nombre positif requis.")
                    except ValueError: print("❌ Entrée invalide.")
                    except (KeyboardInterrupt, EOFError): print("\nOpération annulée."); nb_phrases = -1; break

                if nb_phrases <= 0: continue

                print(f"\n🤖 Génération du résumé ({nb_phrases} phrases)...")
                resume = resumer_texte(texte_extrait, LANGUE, nb_phrases)
                print("\n--- Résumé ---")
                print(resume)
                print("--- Fin du Résumé ---")

                print("\n🤖 Extraction des mots-clés...")
                mots_cles = extraire_mots_cles(texte_extrait, LANGUE, nb_mots=7)
                if mots_cles:
                    print("\n--- Mots-Clés (max 7) ---")
                    print(", ".join(mots_cles))
                    print("--- Fin des Mots-Clés ---")
            else:
                 # Le message d'erreur de extract_texte_url devrait déjà être affiché
                 print("❌ Impossible d'extraire le texte de l'URL (raison inconnue après succès apparent).") # Fallback

        elif choix == '3':
            print("\n🤖 Au revoir ! 👋")
            break
        else:
            print("\n❌ Choix invalide. Veuillez entrer 1, 2 ou 3.")

        print("\n" + "="*50) # Séparateur

# =====================================
#  CELLULE 4 : Lancement du Chatbot (Mode Texte)
# =====================================
# Décommentez la ligne ci-dessous pour lancer en mode texte.
#lancer_chatbot_texte()

# =====================================
#  CELLULE 5 : Alternative avec Interface ipywidgets
# =====================================
# Widgets
text_input_area = widgets.Textarea(placeholder='Collez votre texte ici...', layout=widgets.Layout(width='95%', height='180px'), description='Texte:', disabled=not nltk_download_success)
url_input = widgets.Text(placeholder='Ou entrez une URL ici...', layout=widgets.Layout(width='95%'), description='URL:', disabled=not nltk_download_success)
sentences_slider = widgets.IntSlider(value=3, min=1, max=20, step=1, description='Phrases:', layout=widgets.Layout(width='60%'), disabled=not nltk_download_success, readout_format='d')
summarize_button = widgets.Button(description='Résumer', button_style='success', tooltip='Lancer le résumé et l\'extraction', icon='compress', disabled=not nltk_download_success, layout=widgets.Layout(width='auto'))
output_area = widgets.Output(layout=widgets.Layout(width='95%', min_height='150px', border='1px solid lightgray', padding='10px', margin='10px 0 0 0', overflow_y='auto'))
status_label = widgets.Label(value="Prêt." if nltk_download_success else "Erreur NLTK - Voir logs.")

# Fonction appelée par le bouton
def on_summarize_button_clicked(b):
    summarize_button.disabled = True
    summarize_button.icon = 'spinner'
    summarize_button.description = 'Traitement...'
    status_label.value = "⏳ Initialisation..."
    output_area.clear_output(wait=True)

    texte_a_resumer = None
    source = ""
    texte_colle = text_input_area.value.strip()
    url = url_input.value.strip()

    with output_area:
        if texte_colle:
            status_label.value = "🤖 Analyse du texte collé..."
            print("🤖 Analyse du texte collé...")
            texte_a_resumer = texte_colle
            source = "Texte fourni"
            url_input.value = ""
        elif url:
            status_label.value = f"🤖 Extraction depuis URL..."
            print(f"🤖 Extraction depuis URL...")
            texte_a_resumer, erreur = extraire_texte_url(url)
            if erreur:
                status_label.value = f"❌ Erreur URL: {erreur}"
                print(f"❌ Erreur URL: {erreur}")
                summarize_button.disabled = False; summarize_button.icon = 'compress'; summarize_button.description = 'Résumer'
                return
            if texte_a_resumer:
                status_label.value = "✅ Texte extrait."
                print(f"✅ Texte extrait ({len(texte_a_resumer)} caractères)")
                source = f"URL"
                text_input_area.value = ""
            else:
                status_label.value = "❌ Échec extraction (pas de texte trouvé)."
                print("❌ Échec extraction (pas de texte trouvé).")
                summarize_button.disabled = False; summarize_button.icon = 'compress'; summarize_button.description = 'Résumer'
                return
        else:
            status_label.value = "⚠️ Veuillez fournir du texte ou une URL."
            print("⚠️ Veuillez fournir du texte ou une URL.")
            summarize_button.disabled = False; summarize_button.icon = 'compress'; summarize_button.description = 'Résumer'
            return

        nb_phrases = sentences_slider.value
        status_label.value = f"⏳ Résumé ({nb_phrases} phrases) & Mots-clés..."
        print(f"\n--- Génération Résumé ({nb_phrases} phrases) ---")
        resume = resumer_texte(texte_a_resumer, LANGUE, nb_phrases)
        print(resume)
        print("--- Fin Résumé ---")

        print("\n--- Extraction Mots-Clés (max 7) ---")
        mots_cles = extraire_mots_cles(texte_a_resumer, LANGUE, nb_mots=7)
        if mots_cles:
            print(", ".join(mots_cles))
        else:
            print("[Aucun mot-clé pertinent trouvé ou extraction impossible]")
        print("--- Fin Mots-Clés ---")

        status_label.value = f"✅ Terminé ({source})."

    summarize_button.disabled = False
    summarize_button.icon = 'compress'
    summarize_button.description = 'Résumer'

# Lier la fonction au clic du bouton
summarize_button.on_click(on_summarize_button_clicked)

# Afficher l'interface
if nltk_download_success:
    print("\n" + "="*50)
    print("🤖 Interface Interactive du Résumeur 🤖")
    print("   Collez du texte OU entrez une URL, ajustez le nombre de phrases, puis cliquez sur 'Résumer'.")
    input_section = widgets.VBox([
        widgets.HTML("<b>Texte à résumer :</b>"), text_input_area,
        widgets.HTML("<b>Ou URL d'une page web :</b>"), url_input
    ])
    controls_section = widgets.HBox([sentences_slider, summarize_button], layout=widgets.Layout(margin='10px 0', justify_content='space-between')) # Better spacing
    output_section = widgets.VBox([
        status_label,
        widgets.HTML("<hr style='margin: 5px 0;'>"),
        widgets.HTML("<b>Résultat :</b>"),
        output_area
    ])
    display(widgets.VBox([input_section, controls_section, output_section]))
else:
    missing_str = ', '.join(missing_resources) if 'missing_resources' in globals() and missing_resources else "inconnues"
    print("\n" + "="*50)
    print(f"❌ L'interface interactive ne peut pas être lancée car les ressources NLTK essentielles ({missing_str}) n'ont pas pu être chargées.")
    print("   Veuillez corriger les erreurs dans la sortie \"Téléchargement des ressources NLTK\" ci-dessus et ré-exécuter la cellule.")
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.3/97.3 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 53.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.5 MB/s eta 0:00:00
#   Building wheel for breadability (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
# ⬇️ Téléchargement des ressources NLTK nécessaires (punkt, stopwords, punkt_tab)...
# --- Vérification de 'punkt' ---
#    [INFO] 'punkt' déjà présent.
# --- Vérification de 'stopwords' ---
#    [ACTION] 'stopwords' non trouvé. Tentative de téléchargement...
#    [SUCCESS] 'stopwords' téléchargé avec succès.
# --- Vérification de 'punkt_tab' ---
#    [ACTION] 'punkt_tab' non trouvé. Tentative de téléchargement...
#    [SUCCESS] 'punkt_tab' téléchargé avec succès.
# ✅ Ressources NLTK essentielles trouvées ou téléchargées.
# ✅ Stopwords français chargés.
# ✅ Environnement prêt.
#
# ==================================================
# 🤖 Interface Interactive du Résumeur 🤖
#    Collez du texte OU entrez une URL, ajustez le nombre de phrases, puis cliquez sur 'Résumer'.
# VBox(children=(VBox(children=(HTML(value='<b>Texte à résumer :</b>'), Textarea(value='', description='Texte:',…

# %%
# -*- coding: utf-8 -*-
# =====================================
#  CELLULE 1 : Installation et Setup
# =====================================
# Installez les bibliothèques nécessaires.
# !pip install nltk sumy scikit-learn requests beautifulsoup4 ipywidgets -q

# Importations principales
import nltk
import requests
from bs4 import BeautifulSoup
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer # Alternative: TextRankSummarizer, LexRankSummarizer
from sumy.nlp.stemmers import Stemmer
from sumy.utils import get_stop_words

from sklearn.feature_extraction.text import TfidfVectorizer
import ipywidgets as widgets
from IPython.display import display, clear_output

import warnings
warnings.filterwarnings('ignore') # Pour masquer les avertissements potentiels
import urllib.error # Pour attraper spécifiquement les erreurs réseau NLTK

# Téléchargement des ressources NLTK (version avec punkt_tab)
print("⬇️ Téléchargement des ressources NLTK nécessaires (punkt, stopwords, punkt_tab)...")
nltk_download_success = True
missing_resources = []
resources_to_download = [
    ('tokenizers/punkt', 'punkt'),
    ('corpora/stopwords', 'stopwords'),
    ('tokenizers/punkt_tab', 'punkt_tab') # Ajout de punkt_tab
]

try:
    for resource_path, resource_name in resources_to_download:
        print(f"--- Vérification de '{resource_name}' ---")
        try:
            nltk.data.find(resource_path)
            print(f"   [INFO] '{resource_name}' déjà présent.")
        except LookupError:
            print(f"   [ACTION] '{resource_name}' non trouvé. Tentative de téléchargement...")
            try:
                nltk.download(resource_name, quiet=True)
                # Vérifier à nouveau après la tentative de téléchargement
                nltk.data.find(resource_path)
                print(f"   [SUCCESS] '{resource_name}' téléchargé avec succès.")
            except urllib.error.URLError as e:
                print(f"   [ERREUR] Réseau pendant le téléchargement de '{resource_name}': {e}")
                missing_resources.append(resource_name)
                nltk_download_success = False
            except LookupError:
                print(f"   [ERREUR] Échec de la localisation de '{resource_name}' après tentative de téléchargement.")
                missing_resources.append(resource_name)
                nltk_download_success = False
            except Exception as e:
                 print(f"   [ERREUR] Inattendue pendant le téléchargement de '{resource_name}': {e}")
                 missing_resources.append(resource_name)
                 nltk_download_success = False

    # --- Message final sur les ressources NLTK ---
    if not missing_resources:
        print("✅ Ressources NLTK essentielles trouvées ou téléchargées.")
    else:
        print(f"⚠️ Certaines ressources NLTK n'ont pas pu être chargées : {', '.join(missing_resources)}")
        # nltk_download_success est déjà False si missing_resources n'est pas vide


except Exception as e:
    # Erreur générale en dehors des blocs de téléchargement
    print(f"❌ Erreur générale inattendue lors de la préparation des ressources NLTK : {e}")
    nltk_download_success = False

# Définition de la langue et des stop words
LANGUE = "french"
STOP_WORDS_FR_NLTK = []
STOP_WORDS_FR_SUMY = []

if nltk_download_success:
    try:
        STOP_WORDS_FR_NLTK = nltk.corpus.stopwords.words(LANGUE)
        STOP_WORDS_FR_SUMY = get_stop_words(LANGUE)
        print("✅ Stopwords français chargés.")
    except Exception as e:
        print(f"❌ Erreur lors du chargement des stopwords français : {e}")
        nltk_download_success = False

# --- Message final sur l'état de l'environnement ---
if nltk_download_success:
    print("✅ Environnement prêt.")
else:
    print("⚠️ Environnement partiellement prêt ou échec critique. Vérifiez les messages d'erreur NLTK ci-dessus.")


# =====================================
#  CELLULE 2 : Fonctions Utilitaires
# =====================================

def resumer_texte(texte, langue, nb_phrases):
    """
    Résume le texte donné en utilisant Sumy (LSA par défaut).
    """
    if not nltk_download_success:
         # Message plus précis basé sur les ressources manquantes si possible
         missing_str = ', '.join(missing_resources) if 'missing_resources' in globals() and missing_resources else "inconnues"
         return f"[ERREUR: RESSOURCES NLTK MANQUANTES ({missing_str})]"
    if not texte or not isinstance(texte, str) or texte.isspace():
        return "[Erreur: Texte vide ou invalide]"
    if not isinstance(nb_phrases, int) or nb_phrases <= 0:
        return "[Erreur: Nombre de phrases invalide]"

    try:
        # Utilisation explicite du tokenizer pour la langue spécifiée
        parser = PlaintextParser.from_string(texte, Tokenizer(langue))
        stemmer = Stemmer(langue)
        summarizer = LsaSummarizer(stemmer)
        # S'assurer que les stopwords sont bien ceux de la langue
        summarizer.stop_words = STOP_WORDS_FR_SUMY if STOP_WORDS_FR_SUMY else get_stop_words(langue)

        resume_phrases = summarizer(parser.document, nb_phrases)
        resume_final = " ".join([str(phrase) for phrase in resume_phrases])

        if not resume_final.strip():
             # Essayer d'obtenir le nombre total de phrases pour aider au diagnostic
             try:
                 total_phrases = len(parser.document.sentences)
                 return f"[Info: Le résumé généré est vide. Le texte original contient {total_phrases} phrases. Vérifiez le texte ou le nombre de phrases demandé ({nb_phrases}).]"
             except:
                 return "[Info: Le résumé généré est vide. Le texte original était peut-être trop court ou le nombre de phrases demandé trop élevé.]"
        return resume_final
    except LookupError as le:
        # Attraper spécifiquement les LookupError qui pourraient encore survenir
        return f"[Erreur NLTK pendant le résumé: Ressource manquante - {le}. Vérifiez l'installation NLTK.]"
    except Exception as e:
        # Inclure le type d'erreur pour faciliter le débogage
        return f"[Erreur pendant le résumé ({type(e).__name__}): {e}]"


def extraire_texte_url(url):
    """
    Extrait le contenu textuel principal d'une page web.
    """
    if not url or not url.startswith(('http://', 'https://')):
        return None, "URL invalide (doit commencer par http:// ou https://)."

    try:
        headers = {'User-Agent': 'Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)'}
        reponse = requests.get(url, headers=headers, timeout=15, allow_redirects=True)
        reponse.raise_for_status()
        reponse.encoding = reponse.apparent_encoding

        soup = BeautifulSoup(reponse.content, 'html.parser')

        for element in soup(["script", "style", "header", "footer", "nav", "aside", "form", "noscript", "img", "figure", "iframe"]):
            element.decompose() # Enlever plus d'éléments non textuels

        contenu_principal = soup.find('article') or soup.find('main') or soup.find(role='main')
        if not contenu_principal:
             contenu_principal = soup.find('body')

        if contenu_principal:
            # Remplacer les sauts de ligne par des espaces et nettoyer
            texte_brut = contenu_principal.get_text(separator=' ', strip=True)
        else:
             texte_brut = soup.get_text(separator=' ', strip=True)

        texte_nettoye = ' '.join(texte_brut.split())

        if not texte_nettoye or len(texte_nettoye) < 50: # Seuil minimum de caractères
             paragraphes = soup.find_all('p')
             if paragraphes:
                 texte_brut_p = ' '.join([p.get_text(strip=True) for p in paragraphes if p.get_text(strip=True)])
                 texte_nettoye_p = ' '.join(texte_brut_p.split())
                 # Utiliser la version <p> seulement si elle est significativement plus longue
                 if len(texte_nettoye_p) > len(texte_nettoye) * 1.2:
                      texte_nettoye = texte_nettoye_p

        if not texte_nettoye:
            return None, "Impossible d'extraire du contenu textuel significatif."

        return texte_nettoye, None

    except requests.exceptions.Timeout:
        return None, f"Erreur: Délai d'attente dépassé pour l'URL."
    except requests.exceptions.HTTPError as e:
         return None, f"Erreur HTTP {e.response.status_code}."
    except requests.exceptions.RequestException as e:
        # Essayer de donner une erreur plus spécifique si possible (ex: DNS, Connexion)
        error_type = type(e).__name__
        return None, f"Erreur de connexion ({error_type}). Vérifiez l'URL et la connexion."
    except Exception as e:
        return None, f"Erreur inattendue (analyse HTML?): {type(e).__name__}"


def extraire_mots_cles(texte, langue, nb_mots=7):
    """
    Extrait les mots-clés via TF-IDF.
    """
    if not nltk_download_success or not STOP_WORDS_FR_NLTK:
         print("[Avertissement: Mots-clés non extraits (ressources NLTK ou stopwords manquants)]")
         return []
    if not texte or not isinstance(texte, str) or texte.isspace() or len(texte.split()) < 5: # Besoin d'un minimum de mots
        print("[Info: Texte trop court pour l'extraction de mots-clés pertinents]")
        return []

    try:
        vectorizer = TfidfVectorizer(stop_words=STOP_WORDS_FR_NLTK, max_features=1000, ngram_range=(1, 2))
        tfidf_matrix = vectorizer.fit_transform([texte])

        feature_names = vectorizer.get_feature_names_out()
        scores = tfidf_matrix.toarray()[0]
        scored_words = zip(scores, feature_names)
        sorted_words = sorted(scored_words, key=lambda x: x[0], reverse=True)
        mots_cles = [word for score, word in sorted_words if score > 0.02][:nb_mots] # Seuil légèrement augmenté

        return mots_cles
    except ValueError as ve:
        if "empty vocabulary" in str(ve):
            print("[Info: Vocabulaire vide après filtrage pour TF-IDF]")
            return []
        else:
            print(f"[Avertissement: Erreur TF-IDF (ValueError): {ve}]")
            return []
    except Exception as e:
        print(f"[Avertissement: Erreur TF-IDF (Inattendue): {e}]")
        return []

# =====================================
#  CELLULE 3 : Interface Chatbot (Texte) - Pas de changements majeurs nécessaires ici
# =====================================
def lancer_chatbot_texte():
    """Lance l'interaction principale du chatbot en mode texte."""
    if not nltk_download_success:
        missing_str = ', '.join(missing_resources) if 'missing_resources' in globals() and missing_resources else "inconnues"
        print(f"❌ Le chatbot ne peut pas démarrer car les ressources NLTK essentielles ({missing_str}) n'ont pas pu être chargées.")
        print("   Veuillez vérifier les messages d'erreur ci-dessus et ré-exécuter la cellule.")
        return

    print("\n" + "="*50)
    print("🤖 Bonjour ! Je suis votre assistant résumeur de texte.")
    print("="*50)

    while True:
        print("\nQue souhaitez-vous faire ?")
        print("1. Résumer un texte que vous allez coller.")
        print("2. Résumer le contenu d'une page web (via URL).")
        print("3. Quitter.")

        choix = ""
        try:
            choix = input("Votre choix (1, 2 ou 3) : ").strip()
        except EOFError: print("\nEntrée fermée. Arrêt."); break
        except KeyboardInterrupt: print("\nInterruption détectée. Arrêt."); break

        if choix == '1':
            print("\n🤖 Très bien ! Collez votre texte ci-dessous (Entrée sur ligne vide pour finir):")
            lignes = []
            try:
                while True:
                    ligne = input()
                    if ligne or ligne == "": # Accepter ligne vide pour finir
                         if ligne: lignes.append(ligne)
                         elif lignes: break # Arrêter si ligne vide ET on a déjà du texte
                         else: print("   (Continuez à coller ou Entrée sur ligne vide pour finir)") # Rappel si vide au début
                    # Si input() retourne None ou autre chose (ne devrait pas arriver normalement)
                    # else:
                    #     if lignes: break
                    #     else: print("\nSaisie invalide/annulée."); lignes=None; break

            except EOFError:
                if not lignes: print("\nSaisie annulée (EOF)."); continue
                print("\nFin de saisie détectée (EOF).")
            except KeyboardInterrupt: print("\nSaisie annulée (Ctrl+C)."); continue

            if not lignes: continue

            texte_utilisateur = "\n".join(lignes)
            print(f"\n🤖 Texte reçu ! ({len(texte_utilisateur)} caractères)")

            nb_phrases = 0
            while True:
                try:
                    nb_phrases_str = input("Combien de phrases pour le résumé ? (Nombre > 0) : ").strip()
                    if not nb_phrases_str: continue
                    nb_phrases = int(nb_phrases_str)
                    if nb_phrases > 0: break
                    else: print("❌ Nombre positif requis.")
                except ValueError: print("❌ Entrée invalide (nombre entier requis).")
                except (KeyboardInterrupt, EOFError): print("\nOpération annulée."); nb_phrases = -1; break

            if nb_phrases <= 0: continue

            print(f"\n🤖 Génération du résumé ({nb_phrases} phrases)...")
            resume = resumer_texte(texte_utilisateur, LANGUE, nb_phrases)
            print("\n--- Résumé ---")
            print(resume)
            print("--- Fin du Résumé ---")

            print("\n🤖 Extraction des mots-clés...")
            mots_cles = extraire_mots_cles(texte_utilisateur, LANGUE, nb_mots=7)
            if mots_cles:
                print("\n--- Mots-Clés (max 7) ---")
                print(", ".join(mots_cles))
                print("--- Fin des Mots-Clés ---")

        elif choix == '2':
            url = ""
            try:
                 url = input("\n🤖 Entrez l'URL de la page web : ").strip()
                 if not url: print("❌ URL vide."); continue
            except (KeyboardInterrupt, EOFError): print("\nOpération annulée."); continue

            print(f"\n🤖 Extraction du texte de : {url}...")
            texte_extrait, erreur = extraire_texte_url(url)

            if erreur:
                print(f"❌ Erreur URL : {erreur}")
                continue

            if texte_extrait:
                print(f"✅ Texte extrait ({len(texte_extrait)} caractères)")
                nb_phrases = 0
                while True:
                    try:
                        nb_phrases_str = input("Combien de phrases pour le résumé ? (Nombre > 0) : ").strip()
                        if not nb_phrases_str: continue
                        nb_phrases = int(nb_phrases_str)
                        if nb_phrases > 0: break
                        else: print("❌ Nombre positif requis.")
                    except ValueError: print("❌ Entrée invalide.")
                    except (KeyboardInterrupt, EOFError): print("\nOpération annulée."); nb_phrases = -1; break

                if nb_phrases <= 0: continue

                print(f"\n🤖 Génération du résumé ({nb_phrases} phrases)...")
                resume = resumer_texte(texte_extrait, LANGUE, nb_phrases)
                print("\n--- Résumé ---")
                print(resume)
                print("--- Fin du Résumé ---")

                print("\n🤖 Extraction des mots-clés...")
                mots_cles = extraire_mots_cles(texte_extrait, LANGUE, nb_mots=7)
                if mots_cles:
                    print("\n--- Mots-Clés (max 7) ---")
                    print(", ".join(mots_cles))
                    print("--- Fin des Mots-Clés ---")
            else:
                 # Le message d'erreur de extract_texte_url devrait déjà être affiché
                 print("❌ Impossible d'extraire le texte de l'URL (raison inconnue après succès apparent).") # Fallback

        elif choix == '3':
            print("\n🤖 Au revoir ! 👋")
            break
        else:
            print("\n❌ Choix invalide. Veuillez entrer 1, 2 ou 3.")

        print("\n" + "="*50) # Séparateur

# =====================================
#  CELLULE 4 : Lancement du Chatbot (Mode Texte)
# =====================================
# Décommentez la ligne ci-dessous pour lancer en mode texte.
# lancer_chatbot_texte()

# =====================================
#  CELLULE 5 : Alternative avec Interface ipywidgets
# =====================================
# Widgets
text_input_area = widgets.Textarea(placeholder='Collez votre texte ici...', layout=widgets.Layout(width='95%', height='180px'), description='Texte:', disabled=not nltk_download_success)
url_input = widgets.Text(placeholder='Ou entrez une URL ici...', layout=widgets.Layout(width='95%'), description='URL:', disabled=not nltk_download_success)
sentences_slider = widgets.IntSlider(value=3, min=1, max=20, step=1, description='Phrases:', layout=widgets.Layout(width='60%'), disabled=not nltk_download_success, readout_format='d')
summarize_button = widgets.Button(description='Résumer', button_style='success', tooltip='Lancer le résumé et l\'extraction', icon='compress', disabled=not nltk_download_success, layout=widgets.Layout(width='auto'))
output_area = widgets.Output(layout=widgets.Layout(width='95%', min_height='150px', border='1px solid lightgray', padding='10px', margin='10px 0 0 0', overflow_y='auto'))
status_label = widgets.Label(value="Prêt." if nltk_download_success else "Erreur NLTK - Voir logs.")

# Fonction appelée par le bouton
def on_summarize_button_clicked(b):
    summarize_button.disabled = True
    summarize_button.icon = 'spinner'
    summarize_button.description = 'Traitement...'
    status_label.value = "⏳ Initialisation..."
    output_area.clear_output(wait=True)

    texte_a_resumer = None
    source = ""
    texte_colle = text_input_area.value.strip()
    url = url_input.value.strip()

    with output_area:
        if texte_colle:
            status_label.value = "🤖 Analyse du texte collé..."
            print("🤖 Analyse du texte collé...")
            texte_a_resumer = texte_colle
            source = "Texte fourni"
            url_input.value = ""
        elif url:
            status_label.value = f"🤖 Extraction depuis URL..."
            print(f"🤖 Extraction depuis URL...")
            texte_a_resumer, erreur = extraire_texte_url(url)
            if erreur:
                status_label.value = f"❌ Erreur URL: {erreur}"
                print(f"❌ Erreur URL: {erreur}")
                summarize_button.disabled = False; summarize_button.icon = 'compress'; summarize_button.description = 'Résumer'
                return
            if texte_a_resumer:
                status_label.value = "✅ Texte extrait."
                print(f"✅ Texte extrait ({len(texte_a_resumer)} caractères)")
                source = f"URL"
                text_input_area.value = ""
            else:
                status_label.value = "❌ Échec extraction (pas de texte trouvé)."
                print("❌ Échec extraction (pas de texte trouvé).")
                summarize_button.disabled = False; summarize_button.icon = 'compress'; summarize_button.description = 'Résumer'
                return
        else:
            status_label.value = "⚠️ Veuillez fournir du texte ou une URL."
            print("⚠️ Veuillez fournir du texte ou une URL.")
            summarize_button.disabled = False; summarize_button.icon = 'compress'; summarize_button.description = 'Résumer'
            return

        nb_phrases = sentences_slider.value
        status_label.value = f"⏳ Résumé ({nb_phrases} phrases) & Mots-clés..."
        print(f"\n--- Génération Résumé ({nb_phrases} phrases) ---")
        resume = resumer_texte(texte_a_resumer, LANGUE, nb_phrases)
        print(resume)
        print("--- Fin Résumé ---")

        print("\n--- Extraction Mots-Clés (max 7) ---")
        mots_cles = extraire_mots_cles(texte_a_resumer, LANGUE, nb_mots=7)
        if mots_cles:
            print(", ".join(mots_cles))
        else:
            print("[Aucun mot-clé pertinent trouvé ou extraction impossible]")
        print("--- Fin Mots-Clés ---")

        status_label.value = f"✅ Terminé ({source})."

    summarize_button.disabled = False
    summarize_button.icon = 'compress'
    summarize_button.description = 'Résumer'

# Lier la fonction au clic du bouton
summarize_button.on_click(on_summarize_button_clicked)

# Afficher l'interface
if nltk_download_success:
    print("\n" + "="*50)
    print("🤖 Interface Interactive du Résumeur 🤖")
    print("   Collez du texte OU entrez une URL, ajustez le nombre de phrases, puis cliquez sur 'Résumer'.")
    input_section = widgets.VBox([
        widgets.HTML("<b>Texte à résumer :</b>"), text_input_area,
        widgets.HTML("<b>Ou URL d'une page web :</b>"), url_input
    ])
    controls_section = widgets.HBox([sentences_slider, summarize_button], layout=widgets.Layout(margin='10px 0', justify_content='space-between')) # Better spacing
    output_section = widgets.VBox([
        status_label,
        widgets.HTML("<hr style='margin: 5px 0;'>"),
        widgets.HTML("<b>Résultat :</b>"),
        output_area
    ])
    display(widgets.VBox([input_section, controls_section, output_section]))
else:
    missing_str = ', '.join(missing_resources) if 'missing_resources' in globals() and missing_resources else "inconnues"
    print("\n" + "="*50)
    print(f"❌ L'interface interactive ne peut pas être lancée car les ressources NLTK essentielles ({missing_str}) n'ont pas pu être chargées.")
    print("   Veuillez corriger les erreurs dans la sortie \"Téléchargement des ressources NLTK\" ci-dessus et ré-exécuter la cellule.")
# Out:
# ⬇️ Téléchargement des ressources NLTK nécessaires (punkt, stopwords, punkt_tab)...
# --- Vérification de 'punkt' ---
#    [INFO] 'punkt' déjà présent.
# --- Vérification de 'stopwords' ---
#    [INFO] 'stopwords' déjà présent.
# --- Vérification de 'punkt_tab' ---
#    [INFO] 'punkt_tab' déjà présent.
# ✅ Ressources NLTK essentielles trouvées ou téléchargées.
# ✅ Stopwords français chargés.
# ✅ Environnement prêt.
#
# ==================================================
# 🤖 Interface Interactive du Résumeur 🤖
#    Collez du texte OU entrez une URL, ajustez le nombre de phrases, puis cliquez sur 'Résumer'.
# VBox(children=(VBox(children=(HTML(value='<b>Texte à résumer :</b>'), Textarea(value='', description='Texte:',…

# %%
url = "https://fr.wikipedia.org/wiki/Intelligence_artificielle"

# Extraction
texte, erreur = extraire_texte_url(url)
if erreur:
    print(erreur)
else:
    # Résumé
    resume = resumer_texte(texte, "french", 5)
    print("Résumé :\n", resume)
# Out:
# Résumé :
#  Certains domaines n'ont progressivement plus été considérés comme faisant partie de l'intelligence artificielle, à mesure qu'une solution efficace était trouvée [ 46 ] ; un phénomène parfois appelé « effet IA » . Au bout du compte, ces jeux d'enfants se révèlent essentiels à la formation de l'esprit, qui dégagent quelques règles pour arbitrer les différents éléments d'appréciation qu'il rencontre, par essais et erreurs. ↑ Dr Jean-François Lemoine, « Révolution dans le développement de médicaments grâce à l'IA » ↑ (en) Andre Esteva, « Dermatologist-level classification of skin cancer with deep neural networks », Nature ,‎ 29 juin 2017 ( lire en ligne ) . ↑ (en) David Silver , Julian Schrittwieser , Karen Simonyan , Ioannis Antonoglou , Aja Huang , Arthur Guez , Thomas Hubert , Lucas Baker , Matthew Lai , Adrian Bolton , Yutian Chen , Timothy Lillicrap , Hui Fan , Laurent Sifre , George van den Driessche , Thore Graepel et Demis Hassabis , « Mastering the game of Go without human knowledge », Nature , vol. (en) Mauro Cazzaniga, Florence Jaumotte, Longji Li, Giovanni Melina, Augustus Panton, Carlo Pizzinelli, Emma Rockall et Marina Tavares, « Gen-AI: Artificial Intelligence and the Future of Work » [PDF] , sur Fonds monétaire international , 14 janvier 2024 .

# %%
# -*- coding: utf-8 -*-
import nltk
import requests
from bs4 import BeautifulSoup
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer
from sumy.nlp.stemmers import Stemmer
from sumy.utils import get_stop_words

import urllib.error
import warnings
warnings.filterwarnings('ignore')

# Téléchargement des ressources NLTK nécessaires
nltk_download_success = True
missing_resources = []
resources_to_download = [
    ('tokenizers/punkt', 'punkt'),
    ('corpora/stopwords', 'stopwords'),
    ('tokenizers/punkt_tab', 'punkt_tab')
]

try:
    for resource_path, resource_name in resources_to_download:
        try:
            nltk.data.find(resource_path)
        except LookupError:
            try:
                nltk.download(resource_name, quiet=True)
                nltk.data.find(resource_path)
            except Exception as e:
                missing_resources.append(resource_name)
                nltk_download_success = False
except Exception:
    nltk_download_success = False

LANGUE = "french"
STOP_WORDS_FR_NLTK = []
STOP_WORDS_FR_SUMY = []

if nltk_download_success:
    try:
        STOP_WORDS_FR_NLTK = nltk.corpus.stopwords.words(LANGUE)
        STOP_WORDS_FR_SUMY = get_stop_words(LANGUE)
    except:
        nltk_download_success = False

def resumer_texte(texte, langue, nb_phrases):
    if not nltk_download_success:
        missing_str = ', '.join(missing_resources) if missing_resources else "inconnues"
        return f"[ERREUR: RESSOURCES NLTK MANQUANTES ({missing_str})]"
    if not texte or not isinstance(texte, str) or texte.isspace():
        return "[Erreur: Texte vide ou invalide]"
    if not isinstance(nb_phrases, int) or nb_phrases <= 0:
        return "[Erreur: Nombre de phrases invalide]"

    try:
        parser = PlaintextParser.from_string(texte, Tokenizer(langue))
        stemmer = Stemmer(langue)
        summarizer = LsaSummarizer(stemmer)
        summarizer.stop_words = STOP_WORDS_FR_SUMY if STOP_WORDS_FR_SUMY else get_stop_words(langue)
        resume_phrases = summarizer(parser.document, nb_phrases)
        resume_final = " ".join([str(phrase) for phrase in resume_phrases])

        if not resume_final.strip():
            try:
                total_phrases = len(parser.document.sentences)
                return f"[Info: Le résumé généré est vide. Le texte original contient {total_phrases} phrases. Vérifiez le texte ou le nombre de phrases demandé ({nb_phrases}).]"
            except:
                return "[Info: Le résumé généré est vide. Le texte original était peut-être trop court ou le nombre de phrases demandé trop élevé.]"
        return resume_final
    except Exception as e:
        return f"[Erreur pendant le résumé ({type(e).__name__}): {e}]"

def extraire_texte_url(url):
    if not url or not url.startswith(('http://', 'https://')):
        return None, "URL invalide (doit commencer par http:// ou https://)."

    try:
        headers = {'User-Agent': 'Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)'}
        reponse = requests.get(url, headers=headers, timeout=15, allow_redirects=True)
        reponse.raise_for_status()
        reponse.encoding = reponse.apparent_encoding
        soup = BeautifulSoup(reponse.content, 'html.parser')

        for element in soup(["script", "style", "header", "footer", "nav", "aside", "form", "noscript", "img", "figure", "iframe"]):
            element.decompose()

        contenu_principal = soup.find('article') or soup.find('main') or soup.find(role='main')
        if not contenu_principal:
            contenu_principal = soup.find('body')

        if contenu_principal:
            texte_brut = contenu_principal.get_text(separator=' ', strip=True)
        else:
            texte_brut = soup.get_text(separator=' ', strip=True)

        texte_nettoye = ' '.join(texte_brut.split())

        if not texte_nettoye or len(texte_nettoye) < 50:
            paragraphes = soup.find_all('p')
            if paragraphes:
                texte_brut_p = ' '.join([p.get_text(strip=True) for p in paragraphes if p.get_text(strip=True)])
                texte_nettoye_p = ' '.join(texte_brut_p.split())
                if len(texte_nettoye_p) > len(texte_nettoye) * 1.2:
                    texte_nettoye = texte_nettoye_p

        if not texte_nettoye:
            return None, "Impossible d'extraire du contenu textuel significatif."

        return texte_nettoye, None

    except requests.exceptions.Timeout:
        return None, "Erreur: Délai d'attente dépassé pour l'URL."
    except requests.exceptions.HTTPError as e:
        return None, f"Erreur HTTP {e.response.status_code}."
    except requests.exceptions.RequestException as e:
        return None, f"Erreur de connexion ({type(e).__name__}). Vérifiez l'URL et la connexion."
    except Exception as e:
        return None, f"Erreur inattendue : {e}"
